# %% [markdown]
# Considerações:
#  - Estou fazendo tudo com views para só no fim transformar em tabelas

# %% [markdown]
# ### Conexão com a base de dados

# %%
############## Importar os módulos necessários para o Notebook:
import ipywidgets as widgets     #---
from sqlalchemy import create_engine

############## Conectar com um servidor SQL na base Alunos 15 ###################### --> Postgres.Alunos15
# %load_ext sql

# Connection format: %sql dialect+driver://username:password@host:port/database
engine = create_engine('postgresql://postgres:pgadmin@localhost/airbnb2')
# %sql postgresql://postgres:pgadmin@localhost/airbnb2

# %% [markdown]
# ## 1NF das tabelas

# %% [markdown]
# ### Passo 1 - fazendo 1NF pra Listing

# %%
# %%sql
# SELECT * FROM Listings
# LIMIT 3;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 3 rows affected.
# [(Decimal('17878'), 'Condo in Rio de Janeiro · ★4.70 · 2 bedrooms · 2 beds · 1 bath', Decimal('68997'), 'Matthias', 'NaN', 'Copacabana', -22.96599, -43.1794, 'Entire home/apt', Decimal('1357.0'), Decimal('5'), Decimal('311'), datetime.date(2023, 12, 22), 1.9, Decimal('1'), Decimal('269'), Decimal('29'), 'NaN'),
#  (Decimal('216461'), 'Rental unit in Rio de Janeiro · 1 bedroom · 1 bed · 1 bath', Decimal('1154263'), 'Zeilma , Da', 'NaN', 'Flamengo', -22.9399, -43.17676, 'Private room', Decimal('734.0'), Decimal('1'), Decimal('0'), None, nan, Decimal('1'), Decimal('365'), Decimal('0'), 'NaN'),
#  (Decimal('326205'), 'Condo in Rio de Janeiro · ★4.57 · 1 bedroom · 1 bed · 1 bath', Decimal('1603206'), 'Bob', 'NaN', 'Copacabana', -22.96825, -43.18237, 'Entire home/apt', Decimal('366.0'), Decimal('3'), Decimal('152'), datetime.date(2023, 11, 21), 1.07, Decimal('5'), Decimal('293'), Decimal('14'), 'NaN')]

# %% [markdown]
# #### Extraindo o nome

# %%
# %%sql
# SELECT
#     CASE WHEN POSITION(' · ' IN name)>0 THEN
#         SPLIT_PART(name,' · ',1)
#     ELSE
#         NULL
#     END AS nome
#     FROM Listings
#     LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 10 rows affected.
# [('Condo in Rio de Janeiro',),
#  ('Rental unit in Rio de Janeiro',),
#  ('Condo in Rio de Janeiro',),
#  ('Rental unit in Rio de Janeiro',),
#  ('Rental unit in Rio de Janeiro',),
#  ('Rental unit in Rio de Janeiro',),
#  ('Loft in Rio de Janeiro',),
#  ('Loft in Rio de Janeiro',),
#  ('Rental unit in Rio de Janeiro',),
#  ('Rental unit in Rio de Janeiro',)]

# %% [markdown]
# #### Extraindo as avaliações

# %%
# %%sql
# SELECT
#     CASE
#         WHEN POSITION('★' IN name) > 0 THEN
#             CAST(NULLIF(TRIM(
#                 CASE WHEN POSITION(' · ' IN SUBSTRING(name FROM POSITION('★' IN name)+1))>0 THEN
#                     SUBSTRING(
#                         SUBSTRING(name FROM POSITION('★' IN name)+1),
#                         0,
#                         POSITION(' · ' IN SUBSTRING(name FROM POSITION('★' IN name)))
#                     )
#                 ELSE
#                     SUBSTRING(name FROM POSITION('★' IN name)+1)
#                 END
#             ),'New') AS FLOAT)
#         ELSE
#             NULL
#     END AS avaliacao
#     FROM Listings
#     LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 10 rows affected.
# [(4.7,),
#  (None,),
#  (4.57,),
#  (4.72,),
#  (4.81,),
#  (4.96,),
#  (4.82,),
#  (4.9,),
#  (5.0,),
#  (4.0,)]

# %% [markdown]
# #### Extraindo o Nquartos

# %%
# %%sql
# SELECT
#     CASE
#         WHEN POSITION('bedroom' IN name) > 0 THEN
#             CAST(TRIM(
#                 CASE WHEN POSITION(' · ' IN SUBSTRING(name,0,POSITION('bedroom' IN name)))>0 THEN
#                     SUBSTRING(
#                         SUBSTRING(name,0,POSITION('bedroom' IN name)),
#                         LENGTH(SUBSTRING(name,0,POSITION('bedroom' IN name))) - POSITION(' · ' IN REVERSE(SUBSTRING(name,0,POSITION('bedroom' IN name)))) + 1,
#                         LENGTH(SUBSTRING(name,0,POSITION('bedroom' IN name))) - 7
#                     )
#                 ELSE
#                     SUBSTRING(name,0,POSITION('bedroom' IN name))
#                 END
#             ) AS SMALLINT)
#         ELSE
#             0
#     END AS Nquartos
#     FROM Listings
#     LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 10 rows affected.
# [(2,), (1,), (1,), (1,), (2,), (1,), (1,), (1,), (1,), (6,)]

# %% [markdown]
# #### Extraindo o número de camas

# %%
# %%sql
# SELECT
#     CASE
#         WHEN POSITION('beds' IN name) > 0 THEN
#             CAST(TRIM(
#                 CASE WHEN POSITION(' · ' IN SUBSTRING(name,0,POSITION('beds' IN name)))>0 THEN
#                     SUBSTRING(
#                         SUBSTRING(name,0,POSITION('beds' IN name)),
#                         LENGTH(SUBSTRING(name,0,POSITION('beds' IN name))) - POSITION(' · ' IN REVERSE(SUBSTRING(name,0,POSITION('beds' IN name)))) + 1,
#                         LENGTH(SUBSTRING(name,0,POSITION('beds' IN name))) - 4
#                     )
#                 ELSE
#                     SUBSTRING(name,0,POSITION('beds' IN name))
#                 END
#             ) AS SMALLINT)
#         WHEN POSITION('1 bed ' IN name) > 0 THEN
#             1
#         ELSE
#             0
#     END AS Ncamas
#     FROM Listings
#     LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 10 rows affected.
# [(2,), (1,), (1,), (1,), (3,), (1,), (2,), (1,), (1,), (16,)]

# %% [markdown]
# #### Extraindo o número de banheiros (não importa o tipo)

# %%
303587
449391

# %%
# %%sql
# SELECT
#     CASE
#         WHEN POSITION('bath' IN name) > 0 THEN
#             CAST(NULLIF(
#                 REGEXP_REPLACE(
#                     SUBSTRING(
#                         name,
#                         LENGTH(SUBSTRING(name,0,POSITION('bath' IN name))) - POSITION(' · ' IN REVERSE(SUBSTRING(name,0,POSITION('bath' IN name)))) + 1,
#                         POSITION('bath' IN name)),
#                 '[^0-9.]','','g'
#                 ),'')
#              AS FLOAT)
#         ELSE
#             0
#     END AS Nbanheiros
#     FROM Listings
#         WHERE id = 449391
#     LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 1 rows affected.
# [(None,)]

# %% [markdown]
# #### Formatação completa pra Listings e guardando em uma View

# %%
# %%sql
# DROP VIEW IF EXISTS Listings_1NF CASCADE;
# CREATE VIEW Listings_1NF AS
# SELECT
#     id AS listing_id,
#     CASE WHEN POSITION(' · ' IN name)>0 THEN
#         SPLIT_PART(name,' · ',1)
#     ELSE
#         NULL
#     END AS nome ,
#
#     CASE
#         WHEN POSITION('★' IN name) > 0 THEN
#             CAST(NULLIF(TRIM(
#                 CASE WHEN POSITION(' · ' IN SUBSTRING(name FROM POSITION('★' IN name)+1))>0 THEN
#                     SUBSTRING(
#                         SUBSTRING(name FROM POSITION('★' IN name)+1),
#                         0,
#                         POSITION(' · ' IN SUBSTRING(name FROM POSITION('★' IN name)))
#                     )
#                 ELSE
#                     SUBSTRING(name FROM POSITION('★' IN name)+1)
#                 END
#             ),'New') AS FLOAT)
#         ELSE
#             NULL
#     END AS avaliacao,
#
#     CASE
#         WHEN POSITION('bedroom' IN name) > 0 THEN
#             CAST(TRIM(
#                 CASE WHEN POSITION(' · ' IN SUBSTRING(name,0,POSITION('bedroom' IN name)))>0 THEN
#                     SUBSTRING(
#                         SUBSTRING(name,0,POSITION('bedroom' IN name)),
#                         LENGTH(SUBSTRING(name,0,POSITION('bedroom' IN name))) - POSITION(' · ' IN REVERSE(SUBSTRING(name,0,POSITION('bedroom' IN name)))) + 1,
#                         LENGTH(SUBSTRING(name,0,POSITION('bedroom' IN name))) - 7
#                     )
#                 ELSE
#                     SUBSTRING(name,0,POSITION('bedroom' IN name))
#                 END
#             ) AS SMALLINT)
#         ELSE
#             0
#     END AS Nquartos,
#
#     CASE
#         WHEN POSITION('beds' IN name) > 0 THEN
#             CAST(TRIM(
#                 CASE WHEN POSITION(' · ' IN SUBSTRING(name,0,POSITION('beds' IN name)))>0 THEN
#                     SUBSTRING(
#                         SUBSTRING(name,0,POSITION('beds' IN name)),
#                         LENGTH(SUBSTRING(name,0,POSITION('beds' IN name))) - POSITION(' · ' IN REVERSE(SUBSTRING(name,0,POSITION('beds' IN name)))) + 1,
#                         LENGTH(SUBSTRING(name,0,POSITION('beds' IN name))) - 4
#                     )
#                 ELSE
#                     SUBSTRING(name,0,POSITION('beds' IN name))
#                 END
#             ) AS SMALLINT)
#         WHEN POSITION('1 bed ' IN name) > 0 THEN
#             1
#         ELSE
#             0
#     END AS Ncamas,
#
#     CASE
#         WHEN POSITION('bath' IN name) > 0 THEN
#             CAST(NULLIF(
#                 REGEXP_REPLACE(
#                     SUBSTRING(
#                         name,
#                         LENGTH(SUBSTRING(name,0,POSITION('bath' IN name))) - POSITION(' · ' IN REVERSE(SUBSTRING(name,0,POSITION('bath' IN name)))) + 1,
#                         POSITION('bath' IN name)),
#                 '[^0-9.]','','g'
#                 ), '')
#              AS FLOAT)
#         ELSE
#             0
#     END AS Nbanheiros,
#
#
#     host_id,
#     host_name,
#     price,
#     minimum_nights,
#     number_of_reviews,
#     last_review,
#     reviews_per_month,
#     calculated_host_listings_count,
#     availability_365,
#     number_of_reviews_ltm,
#     license
# FROM Listings;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM Listings_1NF LIMIT 50
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 50 rows affected.
# [(Decimal('17878'), 'Condo in Rio de Janeiro', 4.7, 2, 2, 1.0, Decimal('68997'), 'Matthias', Decimal('1357.0'), Decimal('5'), Decimal('311'), datetime.date(2023, 12, 22), 1.9, Decimal('1'), Decimal('269'), Decimal('29'), 'NaN'),
#  (Decimal('216461'), 'Rental unit in Rio de Janeiro', None, 1, 1, 1.0, Decimal('1154263'), 'Zeilma , Da', Decimal('734.0'), Decimal('1'), Decimal('0'), None, nan, Decimal('1'), Decimal('365'), Decimal('0'), 'NaN'),
#  (Decimal('326205'), 'Condo in Rio de Janeiro', 4.57, 1, 1, 1.0, Decimal('1603206'), 'Bob', Decimal('366.0'), Decimal('3'), Decimal('152'), datetime.date(2023, 11, 21), 1.07, Decimal('5'), Decimal('293'), Decimal('14'), 'NaN'),
#  (Decimal('25026'), 'Rental unit in Rio de Janeiro', 4.72, 1, 1, 1.0, Decimal('102840'), 'Viviane', Decimal('865.0'), Decimal('2'), Decimal('275'), datetime.date(2023, 12, 3), 1.67, Decimal('1'), Decimal('228'), Decimal('29'), 'NaN'),
#  (Decimal('326575'), 'Rental unit in Rio de Janeiro', 4.81, 2, 3, 2.0, Decimal('1668565'), 'Maria José', Decimal('368.0'), Decimal('4'), Decimal('227'), datetime.date(2023, 11, 21), 1.58, Decimal('1'), Decimal('245'), Decimal('12'), 'NaN'),
#  (Decimal('216700'), 'Rental unit in Rio de Janeiro', 4.96, 1, 1, 1.0, Decimal('1118486'), 'Moara', Decimal('300.0'), Decimal('3'), Decimal('24'), datetime.date(2023, 11, 5), 0.17, Decimal('2'), Decimal('356'), Decimal('3'), 'NaN'),
#  (Decimal('219250'), 'Loft in Rio de Janeiro', 4.82, 1, 2, 1.0, Decimal('1134264'), 'Ricardo', Decimal('254.0'), Decimal('2'), Decimal('431'), datetime.date(2023, 12, 11), 3.07, Decimal('2'), Decimal('312'), Decimal('25'), 'NaN'),
#  (Decimal('35764'), 'Loft in Rio de Janeiro', 4.9, 1, 1, 1.5, Decimal('153691'), 'Patricia Miranda & Paulo', Decimal('373.0'), Decimal('3'), Decimal('454'), datetime.date(2023, 12, 17), 2.82, Decimal('1'), Decimal('62'), Decimal('36'), 'NaN'),
#  (Decimal('220377'), 'Rental unit in Rio de Janeiro', 5.0, 1, 1, 1.0, Decimal('1142424'), 'Taciana', Decimal('220.0'), Decimal('1'), Decimal('4'), datetime.date(2017, 4, 6), 0.03, Decimal('4'), Decimal('294'), Decimal('0'), 'NaN'),
#  (Decimal('327375'), 'Rental unit in Rio de Janeiro', 4.0, 6, 16, 5.0, Decimal('1673501'), 'Josy', Decimal('5874.0'), Decimal('3'), Decimal('12'), datetime.date(2020, 2, 25), 0.09, Decimal('1'), Decimal('365'), Decimal('0'), 'NaN'),
#  (Decimal('41198'), 'Rental unit in Rio de Janeiro', 4.21, 2, 0, 1.0, Decimal('178975'), 'Nicky', Decimal('1701.0'), Decimal('3'), Decimal('17'), datetime.date(2016, 2, 9), 0.13, Decimal('2'), Decimal('44'), Decimal('0'), 'NaN'),
#  (Decimal('48305'), 'Rental unit in Ipanema', 4.76, 6, 7, 7.0, Decimal('70933'), 'Goitaca', Decimal('6604.0'), Decimal('2'), Decimal('163'), datetime.date(2023, 12, 10), 1.04, Decimal('10'), Decimal('319'), Decimal('36'), 'NaN'),
#  (Decimal('328626'), 'Rental unit in Rio de Janeiro', None, 2, 5, 3.0, Decimal('1675497'), 'Priscila', Decimal('1250.0'), Decimal('20'), Decimal('1'), datetime.date(2012, 2, 21), 0.01, Decimal('1'), Decimal('365'), Decimal('0'), 'NaN'),
#  (Decimal('220705'), 'Rental unit in Rio de Janeiro', None, 1, 2, 2.5, Decimal('1144461'), 'Rachel', Decimal('300.0'), Decimal('3'), Decimal('0'), None, nan, Decimal('2'), Decimal('0'), Decimal('0'), 'NaN'),
#  (Decimal('223073'), 'Loft in Rio de Janeiro', 4.81, 1, 1, 1.0, Decimal('503995'), '❤️ BrUx ❤️', Decimal('779.0'), Decimal('1'), Decimal('463'), datetime.date(2023, 12, 20), 3.11, Decimal('7'), Decimal('338'), Decimal('26'), 'NaN'),
#  (Decimal('48901'), 'Rental unit in Rio', 4.5, 4, 5, 3.0, Decimal('222884'), 'Marcio', Decimal('2566.0'), Decimal('3'), Decimal('24'), datetime.date(2023, 12, 11), 0.23, Decimal('1'), Decimal('308'), Decimal('16'), 'NaN'),
#  (Decimal('329615'), 'Home in Rio de Janeiro', None, 1, 1, 1.0, Decimal('1416853'), 'Maria', Decimal('972.0'), Decimal('1'), Decimal('0'), None, nan, Decimal('1'), Decimal('0'), Decimal('0'), 'NaN'),
#  (Decimal('49179'), 'Rental unit in Rio de Janeiro', 4.82, 1, 1, 1.0, Decimal('224192'), 'David', Decimal('409.0'), Decimal('4'), Decimal('156'), datetime.date(2023, 12, 19), 1.15, Decimal('18'), Decimal('0'), Decimal('28'), 'NaN'),
#  (Decimal('230989'), 'Rental unit in Rio de Janeiro', 4.63, 1, 1, 1.0, Decimal('1207700'), 'Maria Luiza', Decimal('500.0'), Decimal('3'), Decimal('153'), datetime.date(2023, 12, 4), 1.03, Decimal('3'), Decimal('1'), Decimal('23'), 'NaN'),
#  (Decimal('231105'), 'Rental unit in Rio de Janeiro', 4.86, 1, 1, 1.0, Decimal('1208327'), 'Christian', Decimal('437.0'), Decimal('3'), Decimal('111'), datetime.date(2023, 12, 12), 0.89, Decimal('8'), Decimal('73'), Decimal('13'), 'NaN'),
#  (Decimal('231497'), 'Rental unit in Rio de Janeiro', 4.74, 1, 1, 1.0, Decimal('1207700'), 'Maria Luiza', Decimal('500.0'), Decimal('3'), Decimal('82'), datetime.date(2023, 11, 21), 0.56, Decimal('3'), Decimal('234'), Decimal('13'), 'NaN'),
#  (Decimal('50759'), 'Home in Rio de Janeiro', 4.57, 6, 10, 7.0, Decimal('233554'), 'Felipe', Decimal('3500.0'), Decimal('1'), Decimal('7'), datetime.date(2017, 1, 8), 0.07, Decimal('2'), Decimal('356'), Decimal('0'), 'NaN'),
#  (Decimal('330913'), 'Rental unit in Rio de Janeiro', 4.78, 1, 2, 1.0, Decimal('500892'), 'Rafael', Decimal('NaN'), Decimal('4'), Decimal('12'), datetime.date(2013, 7, 21), 0.08, Decimal('6'), Decimal('0'), Decimal('0'), 'NaN'),
#  (Decimal('331088'), 'Rental unit in Rio de Janeiro', 4.51, 1, 1, 1.0, Decimal('530231'), 'Yaya', Decimal('105.0'), Decimal('1'), Decimal('53'), datetime.date(2023, 10, 29), 0.37, Decimal('6'), Decimal('271'), Decimal('4'), 'NaN'),
#  (Decimal('51703'), 'Rental unit in Rio de Janeiro', 4.76, 0, 1, 1.0, Decimal('238091'), 'Dália', Decimal('794.0'), Decimal('3'), Decimal('257'), datetime.date(2023, 11, 22), 1.85, Decimal('2'), Decimal('306'), Decimal('31'), 'NaN'),
#  (Decimal('332150'), 'Home in Santa Teresa', 4.78, 1, 7, 5.0, Decimal('406989'), 'Casa 48 Guesthouse', Decimal('186.0'), Decimal('1'), Decimal('78'), datetime.date(2023, 11, 3), 0.57, Decimal('5'), Decimal('287'), Decimal('8'), 'NaN'),
#  (Decimal('332151'), 'Home in Rio de Janeiro', 4.76, 7, 7, 5.0, Decimal('406989'), 'Casa 48 Guesthouse', Decimal('169.0'), Decimal('1'), Decimal('42'), datetime.date(2023, 10, 30), 0.34, Decimal('5'), Decimal('262'), Decimal('4'), 'NaN'),
#  (Decimal('236991'), 'Rental unit in Rio de Janeiro', 4.89, 1, 4, 1.0, Decimal('1241662'), 'Nilda', Decimal('1074.0'), Decimal('5'), Decimal('84'), datetime.date(2023, 12, 22), 0.7, Decimal('2'), Decimal('67'), Decimal('27'), 'NaN'),
#  (Decimal('53533'), 'Home in Joatinga', 4.95, 4, 6, 4.0, Decimal('249439'), 'Sherri & Andre', Decimal('2893.0'), Decimal('3'), Decimal('37'), datetime.date(2023, 11, 12), 0.25, Decimal('1'), Decimal('363'), Decimal('10'), 'NaN'),
#  (Decimal('238802'), 'Rental unit in Rio', 4.79, 3, 4, 2.0, Decimal('235496'), 'Paola', Decimal('1083.0'), Decimal('2'), Decimal('106'), datetime.date(2023, 11, 27), 0.72, Decimal('4'), Decimal('0'), Decimal('34'), 'NaN'),
#  (Decimal('333305'), 'Rental unit in Rio de Janeiro', 4.25, 1, 2, 1.0, Decimal('1698297'), 'Rodrigo', Decimal('2348.0'), Decimal('2'), Decimal('4'), datetime.date(2016, 8, 24), 0.04, Decimal('1'), Decimal('363'), Decimal('0'), 'NaN'),
#  (Decimal('60718'), 'Rental unit in Rio de Janeiro', 4.8, 4, 4, 2.0, Decimal('292870'), 'Tânia', Decimal('1300.0'), Decimal('6'), Decimal('11'), datetime.date(2023, 11, 24), 0.07, Decimal('1'), Decimal('330'), Decimal('3'), 'NaN'),
#  (Decimal('336502'), 'Rental unit in Rio de Janeiro', 4.82, 1, 3, 1.0, Decimal('241334'), 'Andrea', Decimal('793.0'), Decimal('4'), Decimal('24'), datetime.date(2023, 12, 14), 0.17, Decimal('4'), Decimal('215'), Decimal('22'), 'NaN'),
#  (Decimal('337345'), 'Rental unit in Rio de Janeiro', None, 1, 2, 1.0, Decimal('1714680'), 'Katiuscia', Decimal('2411.0'), Decimal('1'), Decimal('0'), None, nan, Decimal('1'), Decimal('365'), Decimal('0'), 'NaN'),
#  (Decimal('239531'), 'Rental unit in Rio de Janeiro', 4.59, 1, 2, 1.0, Decimal('792218'), 'Levy', Decimal('877.0'), Decimal('2'), Decimal('113'), datetime.date(2023, 11, 20), 0.77, Decimal('10'), Decimal('264'), Decimal('16'), 'NaN'),
#  (Decimal('245951'), 'Rental unit in Rio de Janeiro', 4.88, 1, 2, 1.0, Decimal('1289982'), 'Carnaval Turismo', Decimal('443.0'), Decimal('3'), Decimal('16'), datetime.date(2023, 11, 12), 0.11, Decimal('1'), Decimal('80'), Decimal('3'), 'NaN'),
#  (Decimal('64795'), 'Rental unit in Rio de Janeiro', 4.73, 3, 4, 2.5, Decimal('93005'), 'Andrea', Decimal('1600.0'), Decimal('3'), Decimal('70'), datetime.date(2023, 11, 22), 0.45, Decimal('1'), Decimal('0'), Decimal('22'), 'NaN'),
#  (Decimal('340432'), 'Rental unit in Rio de Janeiro', 4.83, 1, 4, 1.0, Decimal('1450861'), 'Leila', Decimal('680.0'), Decimal('5'), Decimal('236'), datetime.date(2023, 12, 13), 1.66, Decimal('4'), Decimal('100'), Decimal('29'), 'NaN'),
#  (Decimal('65546'), 'Rental unit in Rio de Janeiro', 4.4, 3, 7, 7.0, Decimal('70933'), 'Goitaca', Decimal('6500.0'), Decimal('2'), Decimal('69'), datetime.date(2023, 7, 13), 0.44, Decimal('10'), Decimal('319'), Decimal('1'), 'NaN'),
#  (Decimal('342874'), 'Rental unit in Rio de Janeiro', 4.92, 1, 2, 1.0, Decimal('829630'), 'Luciana', Decimal('497.0'), Decimal('1'), Decimal('182'), datetime.date(2023, 12, 4), 1.27, Decimal('3'), Decimal('76'), Decimal('31'), 'NaN'),
#  (Decimal('247052'), 'Rental unit in Rio de Janeiro', None, 2, 2, 3.0, Decimal('1295841'), 'Osmar', Decimal('734.0'), Decimal('5'), Decimal('0'), None, nan, Decimal('1'), Decimal('3'), Decimal('0'), 'NaN'),
#  (Decimal('66797'), 'Rental unit in Rio', 4.91, 0, 1, 1.0, Decimal('328096'), 'Carlos', Decimal('696.0'), Decimal('3'), Decimal('293'), datetime.date(2023, 12, 4), 1.88, Decimal('2'), Decimal('143'), Decimal('36'), 'NaN'),
#  (Decimal('70080'), 'Rental unit in Rio', 4.8, 1, 5, 2.0, Decimal('319672'), 'Valeria', Decimal('1293.0'), Decimal('2'), Decimal('555'), datetime.date(2023, 12, 23), 3.8, Decimal('5'), Decimal('0'), Decimal('65'), 'NaN'),
#  (Decimal('247779'), 'Rental unit in Rio de Janeiro', 4.76, 1, 1, 1.0, Decimal('1298591'), 'Karina', Decimal('543.0'), Decimal('2'), Decimal('154'), datetime.date(2023, 12, 4), 1.05, Decimal('2'), Decimal('16'), Decimal('15'), 'NaN'),
#  (Decimal('346694'), 'Rental unit in Rio de Janeiro', None, 1, 1, 1.0, Decimal('1612576'), 'Jassanan', Decimal('313.0'), Decimal('1'), Decimal('0'), None, nan, Decimal('1'), Decimal('362'), Decimal('0'), 'NaN'),
#  (Decimal('347295'), 'Condo in Rio de Janeiro', 4.19, 1, 1, 1.0, Decimal('1603206'), 'Bob', Decimal('379.0'), Decimal('3'), Decimal('74'), datetime.date(2023, 7, 3), 0.52, Decimal('5'), Decimal('31'), Decimal('4'), 'NaN'),
#  (Decimal('70547'), 'Townhouse in Rio de Janeiro', 4.92, 1, 1, 1.5, Decimal('357995'), 'Isa & Paolo', Decimal('184.0'), Decimal('3'), Decimal('89'), datetime.date(2023, 12, 14), 0.57, Decimal('2'), Decimal('249'), Decimal('6'), 'NaN'),
#  (Decimal('347820'), 'Rental unit in Rio de Janeiro', 4.86, 3, 4, 2.0, Decimal('235496'), 'Paola', Decimal('981.0'), Decimal('2'), Decimal('351'), datetime.date(2023, 11, 13), 2.44, Decimal('4'), Decimal('321'), Decimal('31'), 'NaN'),
#  (Decimal('248756'), 'Condo in Rio de Janeiro', 4.76, 2, 2, 1.5, Decimal('804664'), 'Bernardo', Decimal('1100.0'), Decimal('3'), Decimal('160'), datetime.date(2023, 12, 4), 1.08, Decimal('1'), Decimal('0'), Decimal('22'), 'NaN'),
#  (Decimal('249323'), 'Rental unit in Rio de Janeiro', 4.78, 2, 2, 2.5, Decimal('1306210'), 'Raphael', Decimal('607.0'), Decimal('1'), Decimal('144'), datetime.date(2023, 12, 11), 0.98, Decimal('1'), Decimal('0'), Decimal('31'), 'NaN')]

# %% [markdown]
# ### Passo 2 - Fazendo 1NF pra Calendar

# %%
# %%sql
# SELECT * FROM Calendar LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "calendar" does not exist
# LINE 1: SELECT * FROM Calendar LIMIT 10
#                       ^
#
# [SQL: SELECT * FROM Calendar LIMIT 10]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# ALTER TABLE Calendar RENAME TO Calendar_1NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "calendar" does not exist
#
# [SQL: ALTER TABLE Calendar RENAME TO Calendar_1NF;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Passo 3 - Fazendo 1NF pra Reviews

# %%
# %%sql
# SELECT * FROM Reviews LIMIT 3
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "reviews" does not exist
# LINE 1: SELECT * FROM Reviews LIMIT 3
#                       ^
#
# [SQL: SELECT * FROM Reviews LIMIT 3]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# ALTER TABLE Reviews RENAME TO Reviews_1NF;
# ALTER TABLE Reviews_1NF RENAME COLUMN id TO id_review;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "reviews" does not exist
#
# [SQL: ALTER TABLE Reviews RENAME TO Reviews_1NF;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## 2NF das tabelas

# %% [markdown]
# ### 2NF da tabela Listing 1NF (já está em 2NF)

# %%
# %sql SELECT * FROM Listings_1NF LIMIT 3
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 3 rows affected.
# [(Decimal('17878'), 'Condo in Rio de Janeiro', 4.7, 2, 2, 1.0, Decimal('68997'), 'Matthias', Decimal('1357.0'), Decimal('5'), Decimal('311'), datetime.date(2023, 12, 22), 1.9, Decimal('1'), Decimal('269'), Decimal('29'), 'NaN'),
#  (Decimal('216461'), 'Rental unit in Rio de Janeiro', None, 1, 1, 1.0, Decimal('1154263'), 'Zeilma , Da', Decimal('734.0'), Decimal('1'), Decimal('0'), None, nan, Decimal('1'), Decimal('365'), Decimal('0'), 'NaN'),
#  (Decimal('326205'), 'Condo in Rio de Janeiro', 4.57, 1, 1, 1.0, Decimal('1603206'), 'Bob', Decimal('366.0'), Decimal('3'), Decimal('152'), datetime.date(2023, 11, 21), 1.07, Decimal('5'), Decimal('293'), Decimal('14'), 'NaN')]

# %%
# %%sql
# ALTER TABLE Listings_1NF RENAME TO Listings_2NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# Done.
# Done.
# []

# %% [markdown]
# ### 2NF da Calendar (já está em 2NF)

# %%
# %%sql
# SELECT * FROM Calendar_1NF LIMIT 4
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "calendar_1nf" does not exist
# LINE 1: SELECT * FROM Calendar_1NF LIMIT 4
#                       ^
#
# [SQL: SELECT * FROM Calendar_1NF LIMIT 4]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# ALTER TABLE Calendar_1NF RENAME TO Calendar_2NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "calendar_1nf" does not exist
#
# [SQL: ALTER TABLE Calendar_1NF RENAME TO Calendar_2NF;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### 2NF da Reviews (já está em 2NF)

# %%
# %%sql
# SELECT * FROM Reviews_1NF LIMIT 4
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "reviews_1nf" does not exist
# LINE 1: SELECT * FROM Reviews_1NF LIMIT 4
#                       ^
#
# [SQL: SELECT * FROM Reviews_1NF LIMIT 4]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# ALTER TABLE Reviews_1NF RENAME TO Reviews_2NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "reviews_1nf" does not exist
#
# [SQL: ALTER TABLE Reviews_1NF RENAME TO Reviews_2NF;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## 3NF das tabelas

# %% [markdown]
# ### 3NF Listings

# %%
# %%sql
# SELECT * FROM Listings_2NF
#  LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 10 rows affected.
# [(Decimal('17878'), 'Condo in Rio de Janeiro', 4.7, 2, 2, 1.0, Decimal('68997'), 'Matthias', Decimal('1357.0'), Decimal('5'), Decimal('311'), datetime.date(2023, 12, 22), 1.9, Decimal('1'), Decimal('269'), Decimal('29'), 'NaN'),
#  (Decimal('216461'), 'Rental unit in Rio de Janeiro', None, 1, 1, 1.0, Decimal('1154263'), 'Zeilma , Da', Decimal('734.0'), Decimal('1'), Decimal('0'), None, nan, Decimal('1'), Decimal('365'), Decimal('0'), 'NaN'),
#  (Decimal('326205'), 'Condo in Rio de Janeiro', 4.57, 1, 1, 1.0, Decimal('1603206'), 'Bob', Decimal('366.0'), Decimal('3'), Decimal('152'), datetime.date(2023, 11, 21), 1.07, Decimal('5'), Decimal('293'), Decimal('14'), 'NaN'),
#  (Decimal('25026'), 'Rental unit in Rio de Janeiro', 4.72, 1, 1, 1.0, Decimal('102840'), 'Viviane', Decimal('865.0'), Decimal('2'), Decimal('275'), datetime.date(2023, 12, 3), 1.67, Decimal('1'), Decimal('228'), Decimal('29'), 'NaN'),
#  (Decimal('326575'), 'Rental unit in Rio de Janeiro', 4.81, 2, 3, 2.0, Decimal('1668565'), 'Maria José', Decimal('368.0'), Decimal('4'), Decimal('227'), datetime.date(2023, 11, 21), 1.58, Decimal('1'), Decimal('245'), Decimal('12'), 'NaN'),
#  (Decimal('216700'), 'Rental unit in Rio de Janeiro', 4.96, 1, 1, 1.0, Decimal('1118486'), 'Moara', Decimal('300.0'), Decimal('3'), Decimal('24'), datetime.date(2023, 11, 5), 0.17, Decimal('2'), Decimal('356'), Decimal('3'), 'NaN'),
#  (Decimal('219250'), 'Loft in Rio de Janeiro', 4.82, 1, 2, 1.0, Decimal('1134264'), 'Ricardo', Decimal('254.0'), Decimal('2'), Decimal('431'), datetime.date(2023, 12, 11), 3.07, Decimal('2'), Decimal('312'), Decimal('25'), 'NaN'),
#  (Decimal('35764'), 'Loft in Rio de Janeiro', 4.9, 1, 1, 1.5, Decimal('153691'), 'Patricia Miranda & Paulo', Decimal('373.0'), Decimal('3'), Decimal('454'), datetime.date(2023, 12, 17), 2.82, Decimal('1'), Decimal('62'), Decimal('36'), 'NaN'),
#  (Decimal('220377'), 'Rental unit in Rio de Janeiro', 5.0, 1, 1, 1.0, Decimal('1142424'), 'Taciana', Decimal('220.0'), Decimal('1'), Decimal('4'), datetime.date(2017, 4, 6), 0.03, Decimal('4'), Decimal('294'), Decimal('0'), 'NaN'),
#  (Decimal('327375'), 'Rental unit in Rio de Janeiro', 4.0, 6, 16, 5.0, Decimal('1673501'), 'Josy', Decimal('5874.0'), Decimal('3'), Decimal('12'), datetime.date(2020, 2, 25), 0.09, Decimal('1'), Decimal('365'), Decimal('0'), 'NaN')]

# %%
# %%sql
# DROP VIEW IF EXISTS Host_3NF CASCADE;
# CREATE VIEW Host_3NF AS
#     SELECT DISTINCT host_id, host_name, calculated_host_listings_count
#
#     FROM Listings_2NF;
#
# DROP VIEW IF EXISTS Listings_3NF CASCADE;
# CREATE VIEW Listings_3NF AS
#     SELECT listing_id, nome, avaliacao, nquartos, ncamas,
#            nbanheiros, host_id, price, minimum_nights, number_of_reviews,
#            last_review, reviews_per_month, availability_365,
#            number_of_reviews_ltm, license
#     FROM Listings_2NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ### 3NF Calendar

# %%
# %%sql
# SELECT * FROM Calendar_2NF LIMIT 3
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "calendar_2nf" does not exist
# LINE 1: SELECT * FROM Calendar_2NF LIMIT 3
#                       ^
#
# [SQL: SELECT * FROM Calendar_2NF LIMIT 3]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# ALTER TABLE Calendar_2NF RENAME TO Calendar_3NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.UndefinedTable) relation "calendar_2nf" does not exist
#
# [SQL: ALTER TABLE Calendar_2NF RENAME TO Calendar_3NF;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### 3NF Reviews

# %%
# %%sql
# SELECT * FROM Reviews_2NF LIMIT 3
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# 3 rows affected.
# [(Decimal('17878'), Decimal('64852'), datetime.date(2010, 7, 15), Decimal('135370'), 'Tia', 'This apartment is in a perfect location -- two blocks from the beach and two blocks from the Copacabana Palace (where anyone famous stays when they a ... (99 characters truncated) ... e apartment is like, so you´ll have no surprises.  Max is very communicative and helpful.  The four of us that stayed here would highly recommend it.'),
#  (Decimal('216700'), Decimal('1511171'), datetime.date(2012, 6, 18), Decimal('2598011'), 'Evelyn', 'A estada foi maravilhosa, ficamos so 3 noites se pudessemos ficariamos mais... mas com certeza voltaremos...o lugar eh maravilhoso, quando chegamos f ... (572 characters truncated) ...  sem duvida recomendamos a hospedagem... Saimos bem contentes e satisfeitos do rio e ja estamos planejando a volta....  Nao percam a oportunidade!!! '),
#  (Decimal('216700'), Decimal('1550596'), datetime.date(2012, 6, 24), Decimal('2465739'), 'Camila', "The apartment is located in the beautiful Laranjeiras neighborhood,  everything there is easy access. There' re bakeries, markets, banks, restaurants ... (862 characters truncated) ... me e bem comfortavel com uma linda sacada. \r<br/>\r<br/>Foi uma pena passarmos somente um dia na casa de Moara. Com certeza, voltaremos na sua casa.")]

# %%
# %%sql
#
# DROP TABLE IF EXISTS Reviews_3NF CASCADE;
# CREATE TABLE Reviews_3NF AS
#     SELECT listing_id, id_review, date, reviewer_id, comments
#     FROM Reviews_2NF;
#
# DROP TABLE IF EXISTS Reviewers_3NF CASCADE;
# CREATE TABLE Reviewers_3NF AS
#     SELECT reviewer_id, reviewer_name
#     FROM Reviews_2NF
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# (psycopg2.errors.WrongObjectType) "reviews_3nf" is not a table
# HINT:  Use DROP VIEW to remove a view.
#
# [SQL: DROP TABLE IF EXISTS Reviews_3NF CASCADE;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## BCNF das tabelas
# Todas as tabelas já estão em BCNF, mas vou transformar elas em TABLES para ficar mais fácil. Isso inclui transformar o price do Calendar em float

# %%
# %%sql
# DROP TABLE IF EXISTS Listings_final CASCADE;
# CREATE TABLE Listings_final (
#     listing_id NUMERIC PRIMARY KEY,
#     nome VARCHAR(255),
#     avaliacao DOUBLE PRECISION,
#     nquartos NUMERIC,
#     ncamas NUMERIC,
#     nbanheiros FLOAT,
#     host_id NUMERIC,
#     price FLOAT,
#     minimum_nights NUMERIC,
#     number_of_reviews NUMERIC,
#     last_review Date,
#     reviews_per_month FLOAT,
#     availability_365 NUMERIC,
#     number_of_reviews_ltm NUMERIC,
#     license VARCHAR(255)
# );
#
# INSERT INTO Listings_final
# SELECT
#     listing_id,
#     nome,
#     avaliacao,
#     nquartos,
#     ncamas,
#     nbanheiros,
#     host_id,
#     price,
#     minimum_nights,
#     number_of_reviews,
#     last_review,
#     reviews_per_month,
#     availability_365,
#     number_of_reviews_ltm,
#     license
# FROM Listings_3NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# Done.
# Done.
# 36008 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS Host_final CASCADE;
# CREATE TABLE Host_final (
#     host_id NUMERIC PRIMARY KEY,
#     host_name VARCHAR(255),
#     calculated_host_listings_count INTEGER
# );
#
# INSERT INTO Host_final
# SELECT
#     host_id,
#     host_name,
#     calculated_host_listings_count
# FROM Host_3NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# Done.
# Done.
# 21980 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS Calendar_final CASCADE;
# CREATE TABLE Calendar_final (
#     calendar_id NUMERIC PRIMARY KEY,
#     listing_id NUMERIC,
#     date DATE,
#     available CHAR,
#     price FLOAT,
#     adjusted_price FLOAT,
#     minimum_nights FLOAT,
#     maximum_nights FLOAT
# );
#
# INSERT INTO Calendar_final
# SELECT
#     calendar_id,
#     listing_id,
#     date,
#     available,
#     CAST(NULLIF(REGEXP_REPLACE(price,'[^0-9.]','','g'),'') AS FLOAT),
#     CAST(NULLIF(REGEXP_REPLACE(adjusted_price,'[^0-9.]','','g'),'') AS FLOAT),
#     minimum_nights,
#     maximum_nights
# FROM Calendar_3NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# Done.
# Done.
# 13145595 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS Reviews_final CASCADE;
# CREATE TABLE Reviews_final (
#     id_review NUMERIC PRIMARY KEY,
#     listing_id NUMERIC,
#     date DATE,
#     reviewer_id NUMERIC,
#     comments TEXT
# );
#
# INSERT INTO Reviews_final
# SELECT
#     id_review,
#     listing_id,
#     date,
#     reviewer_id,
#     comments
# FROM Reviews_3NF;
# Out:
#  * postgresql://postgres:***@localhost/airbnb2
# Done.
# Done.
# 703796 rows affected.
# []
